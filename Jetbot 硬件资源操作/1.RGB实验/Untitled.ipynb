# %%
#引入pytorch
impor torch

#查看pytorch版本
torch.__version__

torch.device('mps')
# Out:
#   Cell In[1], line 2
#     impor torch
#           ^
# SyntaxError: invalid syntax

# %%
import torch

torch.__version__
# Out:
# '2.1.0.dev20230531'
