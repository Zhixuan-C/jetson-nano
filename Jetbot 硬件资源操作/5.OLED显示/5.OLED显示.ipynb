# %% [markdown]
# <center><img src="../imge/CLBLOGO.png" alt="创乐博" style="width: 300px;"/></center>
#
# # OLED显示实验
#
# @－－－－湖南创乐博智能科技有限公司－－－－<br>
# @  文件名：5.OLED显示.ipynb <br>
# @  版本：V2.0 <br>
# @  author: zhulin<br>
# @  说明：OLED显示<br>

# %% [markdown]
# ## 1.载入对应的库

# %%
import time

import Adafruit_SSD1306

from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

# %% [markdown]
# ## 2.申明OLED对象

# %%
# 128x32显示器，硬件I2C:
disp = Adafruit_SSD1306.SSD1306_128_32(rst=None, i2c_bus=1, gpio=1)

# %%
# 初始化库。
disp.begin()
# 清除显示内容
disp.clear()
disp.display()

# %%
#为绘图创建空白图像。
#确保为1位颜色创建模式为“1”的图像（单色）
width = disp.width
height = disp.height
image = Image.new('1', (width, height))

# 载入默认字体
font = ImageFont.load_default()

# 获取要在图像上绘制的绘图对象。
draw = ImageDraw.Draw(image)

while True:
    # 画一个黑色填充框清除图像。
    draw.rectangle((0,0,width,height), outline=0, fill=0)
    draw.text((0,0),"MakeRbo jetbot",font=font,fill=255)
    
    # 显示图像。
    disp.image(image)
    disp.display()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-abda7cd9bae3> in <module>
#      19     disp.image(image)
#      20     disp.display()
# ---> 21     time.sleep(3)
#
# KeyboardInterrupt:
